# %% [markdown]
# <a href="https://colab.research.google.com/github/Serin-Yoon/AI-for-Edustudents/blob/main/week14_numericalprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
#사이킷런의 당뇨병 환자 데이터셋 사용
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
class Neuron:
  #초기화 작업
  def __init__(self):
    self.w = 1.0 #가중치 선언, 초기화
    self.b = 1.0 #절편 선언, 초기화

  #정방향 계산 메서드
  def forpass(self, x):
    y_hat = x*self.w + self.b #y=xw+b
    return y_hat
  
  #역방향 계산 메서드 (오차 역전파, backpropagation)
  def backprop(self, x, err):
    w_grad = x*err
    b_grad = 1*err
    return w_grad, b_grad

  #훈련을 위한 메서드
  def fit(self, x, y, epochs):
    #epoch 수만큼 반복 훈련
    for i in range(epochs):
      for x_i, y_i in zip(x,y):
        y_hat = self.forpass(x_i)
        err = -(y_i - y_hat) #오차 계산
        w_grad, b_grad = self.backprop(x_i, err)
        self.w -= w_grad
        self.b -= b_grad

# %%
x = diabetes.data[:, 2]
y = diabetes.target

# %%
#epoch 100
neuron = Neuron()
neuron.fit(x, y, 100)

plt.scatter(x,y)
pt1 = (-0.1, -0.1*neuron.w + neuron.b)
pt2 = (-0.15, -0.15*neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#epoch 50
neuron = Neuron()
neuron.fit(x, y, 50)

plt.scatter(x,y)
pt1 = (-0.1, -0.1*neuron.w + neuron.b)
pt2 = (-0.15, -0.15*neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#epoch 10
neuron = Neuron()
neuron.fit(x, y, 10)

plt.scatter(x,y)
pt1 = (-0.1, -0.1*neuron.w + neuron.b)
pt2 = (-0.15, -0.15*neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#epoch 1
neuron = Neuron()
neuron.fit(x, y, 1)

plt.scatter(x,y)
pt1 = (-0.1, -0.1*neuron.w + neuron.b)
pt2 = (-0.15, -0.15*neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]])
plt.xlabel('x')
plt.ylabel('y')
plt.show()
